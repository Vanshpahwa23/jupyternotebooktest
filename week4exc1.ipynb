# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('matches.csv',sep=';')

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# 1) Count the total number of matches conducted in the year 2008

# %%
print(df['season'].value_counts())
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
# 2008-58 matches

# %% [markdown]
# 2) Find the city name where maximum and minimum number of matches conducted.

# %%
print(df['city'].value_counts())
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
# max matches -mumbai,least matches-nagpur

# %% [markdown]
# 3) Find total count of matches city wise.

# %%
 print(df['city'].value_counts())
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %% [markdown]
# 4) Find the Team which is maximum and minimum toss winner.

# %%
 print(df['toss_winner'].value_counts())
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
# mumbai indians maximum times toss winner

# %% [markdown]
# 5) Check the toss decision that the team has taken.

# %%
df2=df[['toss_winner','toss_decision']]
df2
# Out:
#                      toss_winner toss_decision
# 0    Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant         field
# 2          Kolkata Knight Riders         field
# 3                Kings XI Punjab         field
# 4    Royal Challengers Bangalore           bat
# ..                           ...           ...
# 751               Mumbai Indians         field
# 752          Chennai Super Kings           bat
# 753               Delhi Capitals         field
# 754          Chennai Super Kings         field
# 755               Mumbai Indians           bat
#
# [756 rows x 2 columns]

# %% [markdown]
# 6) Count the total number of normal and tie matches.

# %%
print(df['result'].value_counts())
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %%
# normal-743,Tie-9

# %% [markdown]
# 7) Find the team names where the match result is tie.

# %%
print(df.loc[df['result']=='tie',['team1','team2']])
# Out:
#                            team1                        team2
# 33                 Gujarat Lions               Mumbai Indians
# 125             Rajasthan Royals        Kolkata Knight Riders
# 189              Kings XI Punjab          Chennai Super Kings
# 387  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400             Delhi Daredevils  Royal Challengers Bangalore
# 475             Rajasthan Royals        Kolkata Knight Riders
# 535             Rajasthan Royals              Kings XI Punjab
# 705        Kolkata Knight Riders               Delhi Capitals
# 746               Mumbai Indians          Sunrisers Hyderabad

# %% [markdown]
# 8) Find the team name who won the match by highest runs.

# %%
# print(df.loc[df['win_by_runs'].value_counts(),['winner']])
print(df.loc[df['win_by_runs'].idxmax(),['winner']])
# Out:
# winner    Mumbai Indians
# Name: 43, dtype: object

# %%
 # Mumbai indians  won by 146 runs

# %% [markdown]
# 9) Find the team name who won the match by lowest runs.

# %%
print(df.loc[df['win_by_runs'].idxmin(),['winner']])
# Out:
# winner    Rising Pune Supergiant
# Name: 1, dtype: object

# %%
# Rising Pune Supergiant won by 0 run

# %% [markdown]
# 10) Find the players who was awarded “Player of the match” more than 3 times.

# %%
# Count occurrences of each player in 'player_of_match' column
player_counts = df['player_of_match'].value_counts()

# Check which players have more than 3 occurrences
players_with_more_than_3 = player_counts[player_counts > 3]
print(players_with_more_than_3)
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# SK Warne           4
# CA Lynn            4
# SS Iyer            4
# ML Hayden          4
# KH Pandya          4
# Name: count, Length: 65, dtype: int64

# %% [markdown]
# 11) Find the player who was awarded as player of the match maximum times.

# %%
# CH gayle has been awarded 21 times

# %% [markdown]
# 12) Find the Venue where the team won the match by highest runs.

# %%
df2=df.loc[df['win_by_runs'].idxmax()]
print(df2)
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
df2=df.loc[df['win_by_runs'].idxmax()]
print(df2)
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
# venue-Feroz Shah Kotla

# %% [markdown]
# 13) Find the Venue where the team won the match by lowest runs.

# %%
df2=df.loc[df['win_by_runs'].idxmin()]
print(df2)
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
# venue-Maharashtra Cricket Association Stadium

# %% [markdown]
# 14) Find the Umpires who did umpiring maximum times.

# %%
df['umpire1'] = pd.to_numeric(df['umpire1'], errors='coerce')
print(df.loc[df['umpire1'].idxmax()])
# Out:
# /var/folders/0w/4d7v1n1s7wd7n4dnv5f69jbh0000gn/T/ipykernel_3764/2462947864.py:2: FutureWarning: The behavior of Series.idxmax with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   print(df.loc[df['umpire1'].idxmax()])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 2
#       1 df['umpire1'] = pd.to_numeric(df['umpire1'], errors='coerce')
# ----> 2 print(df.loc[df['umpire1'].idxmax()])
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df=pd.read_csv('matches.csv',sep=';')

# %%
df_clean_specific = df.dropna(subset=['umpire1','umpire2','umpire3'])

# %%
df_clean_specific
# Out:
#         id  season           city      date                        team1  \
# 636   7894    2018         Mumbai  07/04/18               Mumbai Indians
# 637   7895    2018         Mohali  08/04/18             Delhi Daredevils
# 638   7896    2018        Kolkata  08/04/18  Royal Challengers Bangalore
# 639   7897    2018      Hyderabad  09/04/18             Rajasthan Royals
# 640   7898    2018        Chennai  10/04/18        Kolkata Knight Riders
# ..     ...     ...            ...       ...                          ...
# 750  11346    2019         Mohali  05/05/19          Chennai Super Kings
# 751  11347    2019         Mumbai  05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19          Chennai Super Kings
# 754  11414    2019  Visakhapatnam  10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
print(df['umpire1'].value_counts())
# Out:
# umpire1
# HDPK Dharmasena    73
# Asad Rauf          51
# S Ravi             49
# AK Chaudhary       43
# Aleem Dar          38
#                    ..
# Nanda Kishore       1
# SJA Taufel          1
# A Nanda Kishore     1
# SL Shastri          1
# Sundaram Ravi       1
# Name: count, Length: 61, dtype: int64

# %%
print(df['umpire2'].value_counts())
# Out:
# umpire2
# C Shamshuddin       57
# S Ravi              57
# SJA Taufel          54
# RJ Tucker           38
# CK Nandan           36
#                     ..
# Kumar Dharmasena     1
# SD Fry               1
# SJ Davis             1
# Subroto Das          1
# Ian Gould            1
# Name: count, Length: 65, dtype: int64

# %%
print(df['umpire3'].value_counts())
# Out:
# umpire3
# Nitin Menon                10
# O Nandan                   10
# C Shamshuddin              10
# Anil Chaudhary              9
# S Ravi                      8
# Vineet Kulkarni             8
# Bruce Oxenford              7
# Yeshwant Barde              7
# Anil Dandekar               7
# Chris Gaffaney              6
# Rod Tucker                  5
# Marais Erasmus              5
# Nigel Llong                 4
# A Nanda Kishore             3
# Nanda Kishore               3
# Ian Gould                   3
# A.D Deshmukh                2
# K Ananthapadmanabhan        2
# Virender Kumar Sharma       2
# Kumar Dharmasena            2
# Ulhas Gandhe                2
# KN Anantapadmanabhan        1
# Sundaram Ravi               1
# KN Ananthapadmanabhan       1
# Chettithody Shamshuddin     1
# Name: count, dtype: int64

# %%
df['max_matches'] = df[['umpire1', 'umpire2', 'umpire3']].max(axis=1)

# Display the DataFrame with the new column
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 df['max_matches'] = df[['umpire1', 'umpire2', 'umpire3']].max(axis=1)
#       3 # Display the DataFrame with the new column
#       4 print(df)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:11656, in DataFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11648 @doc(make_doc("max", ndim=2))
#   11649 def max(
#   11650     self,
#    (...)
#   11654     **kwargs,
#   11655 ):
# > 11656     result = super().max(axis, skipna, numeric_only, **kwargs)
#   11657     if isinstance(result, Series):
#   11658         result = result.__finalize__(self, method="max")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:12404, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   12397 def max(
#   12398     self,
# ...

# %% [markdown]
# 15) Find the Total matches played in each season

# %%
print(df['season'].value_counts())
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %% [markdown]
# 16) Find the Total runs in each season

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %% [markdown]
# 17) No. of tosses won by each team

# %%
print(df['toss_winner'].value_counts())
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %% [markdown]
# 18) Visualize the Toss decision across seasons
